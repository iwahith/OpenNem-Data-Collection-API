# %%
import requests
import pandas as pd
import json

url = "https://api.opennem.org.au/weather/station"

headers = {
    'Accept': 'application/json',
    'Content-Type': 'application/json'
}


response = requests.request("GET", url, headers = headers, data={})
myjson = response.json()

print(myjson)

# Serializing json
json_object = json.dumps(myjson, indent=4)
 
# Writing to sample.json
with open("Weather Station.json", "w") as outfile:
    outfile.write(json_object)
# Out:
# [{'code': '009204', 'state': 'WA', 'name_alias': 'Gooseberry Hill', 'registered': None, 'website_url': 'http://www.bom.gov.au/products/IDW60801/IDW60801.94615.shtml', 'altitude': 220, 'lat': -31.94, 'lng': 116.05}, {'code': '009214', 'state': 'WA', 'name_alias': 'Ocean Reef', 'registered': None, 'website_url': 'http://www.bom.gov.au/products/IDW60801/IDW60801.94607.shtml', 'altitude': 10, 'lat': -31.76, 'lng': 115.73}, {'code': '009225', 'state': 'WA', 'name_alias': 'Perth', 'registered': None, 'website_url': 'http://www.bom.gov.au/products/IDW60801/IDW60801.94608.shtml', 'altitude': 25, 'lat': -31.92, 'lng': 115.87}, {'code': '004100', 'state': 'WA', 'name_alias': 'Bedout Island', 'registered': None, 'website_url': 'http://www.bom.gov.au/products/IDW60801/IDW60801.94310.shtml', 'altitude': 9, 'lat': -19.59, 'lng': 119.1}, {'code': '004106', 'state': 'WA', 'name_alias': 'Marble Bar', 'registered': None, 'website_url': 'http://www.bom.gov.au/products/IDW60801/IDW60801.95317.shtml', 'altitude': 182, 'lat': -21.18, 'lng': 119.75}, {'code': '005007', 'state': 'WA', 'name_alias': 'Learmonth', 'registered': None, 'website_url': 'http://www.bom.gov.au/products/IDW60801/IDW60801.94302.shtml', 'altitude': 5, 'lat': -22.24, 'lng': 114.1}, {'code': '004032', 'state': 'WA', 'name_alias': 'Port Hedland', 'registered': None, 'website_url': 'http://www.bom.gov.au/products/IDW60801/IDW60801.94312.shtml', 'altitude': 6, 'lat': -20.37, 'lng': 118.63}, {'code': '009172', 'state': 'WA', 'name_alias': 'Jandakot', 'registered': None, 'website_url': 'http://www.bom.gov.au/products/IDW60801/IDW60801.94609.shtml', 'altitude': 30, 'lat': -32.1, 'lng': 115.88}, {'code': '004083', 'state': 'WA', 'name_alias': 'Karratha', 'registered': None, 'website_url': 'http://www.bom.gov.au/products/IDW60801/IDW60801.95307.shtml', 'altitude': 5, 'lat': -20.71, 'lng': 116.77}, {'code': '005098', 'state': 'WA', 'name_alias': 'Karijini North', 'registered': None, 'website_url': 'http://www.bom.gov.au/products/IDW60801/IDW60801.94330.shtml', 'altitude': 474, 'lat': -22.3, 'lng': 118.45}, {'code': '009111', 'state': 'WA', 'name_alias': 'Karnet', 'registered': None, 'website_url': 'http://www.bom.gov.au/products/IDW60801/IDW60801.95614.shtml', 'altitude': 286, 'lat': -32.44, 'lng': 116.08}, {'code': '009193', 'state': 'WA', 'name_alias': 'Rottnest Island', 'registered': None, 'website_url': 'http://www.bom.gov.au/products/IDW60801/IDW60801.94602.shtml', 'altitude': 43, 'lat': -32.01, 'lng': 115.5}, {'code': '009215', 'state': 'WA', 'name_alias': 'Swanbourne', 'registered': None, 'website_url': 'http://www.bom.gov.au/products/IDW60801/IDW60801.94614.shtml', 'altitude': 41, 'lat': -31.96, 'lng': 115.76}, {'code': '005008', 'state': 'WA', 'name_alias': 'Mardie', 'registered': None, 'website_url': 'http://www.bom.gov.au/products/IDW60801/IDW60801.94306.shtml', 'altitude': 11, 'lat': -21.19, 'lng': 115.98}, {'code': '006022', 'state': 'WA', 'name_alias': 'Gascoyne Junction', 'registered': None, 'website_url': 'http://www.bom.gov.au/products/IDW60801/IDW60801.94410.shtml', 'altitude': 144, 'lat': -25.05, 'lng': 115.21}, {'code': '006044', 'state': 'WA', 'name_alias': 'Denham', 'registered': None, 'website_url': 'http://www.bom.gov.au/products/IDW60801/IDW60801.94402.shtml', 'altitude': 6, 'lat': -25.93, 'lng': 113.53}, {'code': '009114', 'state': 'WA', 'name_alias': 'Lancelin', 'registered': None, 'website_url': 'http://www.bom.gov.au/products/IDW60801/IDW60801.95606.shtml', 'altitude': 2, 'lat': -31.02, 'lng': 115.33}, {'code': '009178', 'state': 'WA', 'name_alias': 'Gingin Airport', 'registered': None, 'website_url': 'http://www.bom.gov.au/products/IDW60801/IDW60801.95612.shtml', 'altitude': 73, 'lat': -31.46, 'lng': 115.86}, {'code': '009240', 'state': 'WA', 'name_alias': 'Bickley', 'registered': None, 'website_url': 'http://www.bom.gov.au/products/IDW60801/IDW60801.95610.shtml', 'altitude': 384, 'lat': -32.01, 'lng': 116.14}, {'code': '005017', 'state': 'WA', 'name_alias': ' ...

# %%
# Locations - All done
# Location

# Stations - All done

# Facility - All done

# Weather Station

# Network Regions
# FuelTechs
# Intervals
# Periods
# Units

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\abdul\Downloads\Summer Internship Project Web Scrapping
